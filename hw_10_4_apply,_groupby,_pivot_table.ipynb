# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('../data/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df[df['Branch'] == 'C']['City'].iloc[0]
# Out:
# 'Naypyitaw'

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(index='Branch', columns='Product line', aggfunc='size')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category["Electronic accessories"].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# Гіпотеза 1: Чи відрізняються покупки за категоріями товарів лояльних клієнтів (Member) від звичайних (Normal)?
#
# Гіпотеза 2: Чи відрізняється середній чек (Total) залежно від способу оплати (Payment)?
#
# Гіпотеза 3: Чи є різниця в середній ціні товарів (Unit price), які купують чоловіки та жінки?

# %%
#перевірка гіпотези 1
df.groupby('Customer type')['Product line'].value_counts(normalize=True) * 100
# Out:
# Customer type  Product line
# Member         Food and beverages        18.762475
#                Sports and travel         17.365269
#                Fashion accessories       17.165669
#                Home and lifestyle        16.566866
#                Electronic accessories    15.568862
#                Health and beauty         14.570858
# Normal         Electronic accessories    18.436874
#                Fashion accessories       18.436874
#                Food and beverages        16.032064
#                Health and beauty         15.831663
#                Sports and travel         15.831663
#                Home and lifestyle        15.430862
# Name: proportion, dtype: float64

# %%
#перевірка гіпотези 2
df.groupby('Payment')['Total'].mean()
# Out:
# Payment
# Cash           326.181890
# Credit card    324.009878
# Ewallet        318.820600
# Name: Total, dtype: float64

# %%
#перевірка гіпотези 3
df.groupby('Gender')['Unit price'].mean()
# Out:
# Gender
# Female    55.263952
# Male      56.081944
# Name: Unit price, dtype: float64

# %% [markdown]
# Висновок щодо гіпотези 1: Покупки лояльних клієнтів (Member) та звичайних клієнтів (Normal) відрізняються за категоріями товарів. Members частіше купують повсякденні товари - продукти харчування, товари для спорту та подорожей, що свідчить про регулярне відвідування магазину. Normal клієнти частіше купують електронні аксесуари та модні товари, що може вказувати на разові або імпульсні покупки. Ці висновки можна використати для прийняття бізнес-рішень: для Member доцільно впроваджувати персональні знижки на регулярні покупки та бонуси за частоту відвідування, а для Normal клієнтів варто використовувати акції на популярні разові покупки (наприклад, електроніку) та пропонувати їм вступ до програми лояльності, а також запровадити крос-продажі.

# %% [markdown]
# Висновок щодо гіпотези 2: Середній чек трохи відрізняється залежно від способу оплати: найвищий він при оплаті готівкою, найнижчий - через електронні гаманці. Це може свідчити, що e-wallet частіше використовують для невеликих покупок. Можна стимулювати електронні гаманці або безготівкові платежі за допомогою кешбеків чи бонусів, щоб підвищити середній чек і зменшити витрати на обробку готівки.

# %% [markdown]
# Висновок щодо гіпотези 3: Середня ціна товарів, які купують чоловіки та жінки, майже не відрізняється: чоловіки витрачають трохи більше, але різниця незначна. Це означає, що гендер не є визначальним фактором при виборі товарів за ціною. Тому для бізнесу доцільніше використовувати універсальні маркетингові пропозиції, а не розробляти окремі акції для чоловіків і жінок.
